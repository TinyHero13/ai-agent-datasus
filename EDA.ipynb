# %%
from pyspark.sql import functions as F
from pyspark.sql.types import *

# %%
df = spark.table("srag_datasus.raw.srag_data")

df.printSchema()

# %%
display(df.limit(100))

# %%
df.columns

# %%
df.count()
